# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from plots import ForexPlotter

from data_handle import (
    ForexDataClean,
    ForexDataLoad,
)

from features import (
    ForexMomentumIndicators,
    ForexTrendIndicators,
    ForexVolatilityIndicators,
    ForexVolumeIndicators,
    ForexMASignals,
    ForexMACDSignals,
    ForexADXSignals,
    ForexParabolicSARSignals,
    ForexRSISignals,
    ForexStochasticSignals,
    ForexWilliamsRSignals,
    ForexCCISignals,
    ForexATRSignals
)

import warnings
warnings.filterwarnings('ignore')

data = ForexDataLoad(file_path = '../data/xauaud.csv').data
ohlcv_data = ForexDataLoad(file_path = '../data/xauaud.csv').data

cleaner = ForexDataClean(data = data)
data = cleaner.fast_cleaner()

trend_data = ForexTrendIndicators(data = data).generate_all_trend_indicators(
    macd_fast_slow_signal = [[12,26,9], [6,13,4], [24,36,8], [7,19,4]], 
    adx_periods = [ 7, 14, 21, 28],
    sar_acc_max = [[0.02, 0.2], [0.04, 0.4], [0.06, 0.6], [0.01, 0.01]]
)
# Out:
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA CLEANER
# ==================================================
#  Available Fuctions
# 1 remove_duplicates
# 2 handle_missing_values
# 3 validate_ohlc_integrity
# 4 handle_outliers
# 5 fast_cleaner
# ==================================================
# ==================================================
# Keep = first and subset = None
# Removed 0 duplicate entries
# ==================================================
# OHLC DATA INTEGRITY VALIDATION
# ==================================================
# No OHLC integrity violations found
# All OHLC values are consistent
# Found 1 missing values
#  dropped: 1 missing values .
# ==================================================
# OHLC DATA INTEGRITY VALIDATION
# ==================================================
# No OHLC integrity violations found
# All OHLC values are consistent
# ==================================================
# TREND INDICATORS
# ==================================================
#  Available Fuctions:
# 1 add_sma
# 2 add_ema
# 3 add_macd
# 4 add_adx
# 5 add_parabolic_sar
# 6 generate_all_trend_indicators
# ==================================================
# ==================================================
# Data Info
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38216 entries, 2017-04-24 02:00:00 to 2025-09-05 20:00:00
# Data columns (total 71 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   close                          38216 non-null  float64
#  1   sma_10                         38207 non-null  float64
#  2   sma_10_slope                   38206 non-null  float64
#  3   sma_20                         38197 non-null  float64
#  4   sma_20_slope                   38196 non-null  float64
#  5   sma_50                         38167 non-null  float64
#  6   sma_50_slope                   38166 non-null  float64
#  7   sma_100                        38117 non-null  float64
#  8   sma_100_slope                  38116 non-null  float64
#  9   sma_200                        38017 non-null  float64
#  10  sma_200_slope                  38016 non-null  float64
#  11  ema_10                         38207 non-null  float64
#  12  ema_10_slope                   38206 non-null  float64
#  13  ema_20                         38197 non-null  float64
#  14  ema_20_slope                   38196 non-null  float64
#  15  ema_50                         38167 non-null  float64
#  16  ema_50_slope                   38166 non-null  float64
#  17  ema_100                        38117 non-null  float64
#  18  ema_100_slope                  38116 non-null  float64
#  19  ema_200                        38017 non-null  float64
#  20  ema_200_slope                  38016 non-null  float64
#  21  macd_12_26                     38183 non-null  float64
#  22  macd_signal_9                  38183 non-null  float64
#  23  macd_hist_fast_12_slow26_sig9  38183 non-null  float64
#  24  macd_12_26_slope               38182 non-null  float64
#  25  macd_signal_9_slope            38182 non-null  float64
#  26  macd_6_13                      38201 non-null  float64
#  27  macd_signal_4                  38195 non-null  float64
#  28  macd_hist_fast_6_slow13_sig4   38201 non-null  float64
#  29  macd_6_13_slope                38200 non-null  float64
#  30  macd_signal_4_slope            38194 non-null  float64
#  31  macd_24_36                     38174 non-null  float64
#  32  macd_signal_8                  38174 non-null  float64
#  33  macd_hist_fast_24_slow36_sig8  38174 non-null  float64
#  34  macd_24_36_slope               38173 non-null  float64
#  35  macd_signal_8_slope            38173 non-null  float64
#  36  macd_7_19                      38195 non-null  float64
#  37  macd_hist_fast_7_slow19_sig4   38195 non-null  float64
#  38  macd_7_19_slope                38194 non-null  float64
#  39  adx_7                          38203 non-null  float64
#  40  adx_7_plus                     38209 non-null  float64
#  41  adx_7_minus                    38209 non-null  float64
#  42  adx_7_slope                    38202 non-null  float64
#  43  adx_7_plus_di_slope            38208 non-null  float64
#  44  adx_7_minus_di_slope           38208 non-null  float64
#  45  adx_14                         38189 non-null  float64
#  46  adx_14_plus                    38202 non-null  float64
#  47  adx_14_minus                   38202 non-null  float64
#  48  adx_14_slope                   38188 non-null  float64
#  49  adx_14_plus_di_slope           38201 non-null  float64
#  50  adx_14_minus_di_slope          38201 non-null  float64
#  51  adx_21                         38175 non-null  float64
#  52  adx_21_plus                    38195 non-null  float64
#  53  adx_21_minus                   38195 non-null  float64
#  54  adx_21_slope                   38174 non-null  float64
#  55  adx_21_plus_di_slope           38194 non-null  float64
#  56  adx_21_minus_di_slope          38194 non-null  float64
#  57  adx_28                         38161 non-null  float64
#  58  adx_28_plus                    38188 non-null  float64
#  59  adx_28_minus                   38188 non-null  float64
#  60  adx_28_slope                   38160 non-null  float64
#  61  adx_28_plus_di_slope           38187 non-null  float64
#  62  adx_28_minus_di_slope          38187 non-null  float64
#  63  sar_0.02_0.2                   38215 non-null  float64
#  64  sar_0.02_0.2_slope             38214 non-null  float64
#  65  sar_0.04_0.4                   38215 non-null  float64
#  66  sar_0.04_0.4_slope             38214 non-null  float64
#  67  sar_0.06_0.6                   38215 non-null  float64
#  68  sar_0.06_0.6_slope             38214 non-null  float64
#  69  sar_0.01_0.01                  38215 non-null  float64
#  70  sar_0.01_0.01_slope            38214 non-null  float64
# dtypes: float64(71)
# memory usage: 21.0 MB
# None
# ==================================================
# Shape of data (38216, 71)
# ==================================================
# 0 rows removed
# ==================================================

# %%
sar_signals = ForexParabolicSARSignals(
    data = trend_data[0],
    parameters = trend_data[1]['sar_params']
)
# Out:
# ==================================================
# PARABOLIC SAR SIGNAL GENERATION
# ==================================================
#  Available Functions:
# 1. sar_trend_signals
# 2. sar_reversal_signals
# 3. sar_distance_signals
# 4. sar_slope_signals
# 5. sar_trend_confirmation_signals
# 6. generate_all_sar_signals
# ==================================================

# %%
trend_signals_data =sar_signals.generate_all_sar_signals()
# Out:
# ==================================================
# Data Info
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38216 entries, 2017-04-24 02:00:00 to 2025-09-05 20:00:00
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   close                             38216 non-null  float64
#  1   sar_0.02_0.2_trend                38216 non-null  int64
#  2   sar_0.04_0.4_trend                38216 non-null  int64
#  3   sar_0.06_0.6_trend                38216 non-null  int64
#  4   sar_0.01_0.01_trend               38216 non-null  int64
#  5   sar_0.02_0.2_reversal             38216 non-null  int64
#  6   sar_0.04_0.4_reversal             38216 non-null  int64
#  7   sar_0.06_0.6_reversal             38216 non-null  int64
#  8   sar_0.01_0.01_reversal            38216 non-null  int64
#  9   sar_0.02_0.2_distance             38216 non-null  int64
#  10  sar_0.04_0.4_distance             38216 non-null  int64
#  11  sar_0.06_0.6_distance             38216 non-null  int64
#  12  sar_0.01_0.01_distance            38216 non-null  int64
#  13  sar_0.02_0.2_slope_signal         38216 non-null  int64
#  14  sar_0.04_0.4_slope_signal         38216 non-null  int64
#  15  sar_0.06_0.6_slope_signal         38216 non-null  int64
#  16  sar_0.01_0.01_slope_signal        38216 non-null  int64
#  17  sar_0.02_0.2_trend_confirmation   38216 non-null  int64
#  18  sar_0.04_0.4_trend_confirmation   38216 non-null  int64
#  19  sar_0.06_0.6_trend_confirmation   38216 non-null  int64
#  20  sar_0.01_0.01_trend_confirmation  38216 non-null  int64
# dtypes: float64(1), int64(20)
# memory usage: 6.4 MB
# None
# ==================================================
# Shape of data (38216, 21)
# ==================================================
# 0 rows removed
# ==================================================

# %%
plotter = ForexPlotter(data = trend_signals_data)
plotter.plot_signals(periods = 240)
