# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Dict, List, Optional, Union
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from plots import ForexPlotter

from data_handle import (
    ForexDataClean,
    ForexDataLoad,
    ForexPctChange,
    ForexQuickLook,
)

from features import (
    ForexTSIndicators,
    ForexCustomIndicators,
    ForexMomentumIndicators,
    ForexTrendIndicators,
    ForexVolatilityIndicators,
    ForexVolumeIndicators,
    ForexMASignals,
    ForexMACDSignals,
    ForexADXSignals,
    ForexParabolicSARSignals,
    ForexRSISignals
)

import warnings
warnings.filterwarnings('ignore')


data = ForexDataLoad(file_path = '../data/xauaud.csv').data
ohlcv_data = ForexDataLoad(file_path = '../data/xauaud.csv').data

cleaner = ForexDataClean(data = data, fast_clean = True)
data = cleaner.data
# Out:
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_dataframe
# 3 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_dataframe
# 3 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA CLEANER
# ==================================================
#  Available Fuctions
# 1 remove_duplicates
# 2 handle_missing_values
# 3 validate_ohlc_integrity
# 4 handle_outliers
# ==================================================
# ==================================================
# Keep = first and subset = None
# Removed 0 duplicate entries
# Found 1 missing values
#  dropped: 1 missing values .
# ==================================================
# OUTLIER DETECTION AND HANDLING
# ==================================================
# Method: quantile, Strategy: cap, Threshold: 3.0
# Remove outliers: False
# --------------------------------------------------
# open: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.81300 - 5218.90300]
# Original range: [1674.10000 - 5476.98000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# high: Found 764 outliers (381 low, 383 high)
# Bounds: [1819.15000 - 5224.87300]
# Original range: [1676.91000 - 5483.78000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# low: Found 766 outliers (383 low, 383 high)
# Bounds: [1816.29450 - 5211.65900]
# Original range: [1671.60000 - 5474.51000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# close: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.85250 - 5218.90300]
# Original range: [1672.21000 - 5477.23000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# volume: Found 48 outliers (0 low, 48 high)
# Bounds: [0.00000 - 0.00000]
# Original range: [0.00000 - 9910.00000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# ==================================================
# SUMMARY: Found 3110 outliers (not removed)
# Use remove=True to handle these outliers
# ==================================================
# ==================================================
# OHLC DATA INTEGRITY VALIDATION
# ==================================================
# No OHLC integrity violations found
# All OHLC values are consistent

# %%
momentum_data = ForexMomentumIndicators(data = data).generate_all_momentum_indicators(
    stochastic_periods = [[14, 3, 3], [28, 6, 6]],
    rsi_periods = [[14, 21, 28], [9, 16, 18]],
    williams_periods = [[14, 21, 28], [9, 16, 18]],
    momentum_periods = [[14, 21, 28], [9, 16, 18], [10, 14, 20]],
    cci_periods = [[14, 21, 28], [9, 16, 18]],
)
# Out:
# ==================================================
# MOMENTUM INDICATORS
# ==================================================
#  Available Fuctions
# 1 add_rsi
# 2 add_stochastic
# 3 add_williams_r
# 4 add_cci
# 5 add_momentum
# 6 generate_all_momentum_indicators
# ==================================================
# ==================================================
# Data Info
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38216 entries, 2017-04-24 02:00:00 to 2025-09-05 20:00:00
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   close                          38216 non-null  float64
#  1   rsi_[14, 21, 28]               38202 non-null  float64
#  2   rsi_[14, 21, 28]_slope         38201 non-null  float64
#  3   rsi_[9, 16, 18]                38207 non-null  float64
#  4   rsi_[9, 16, 18]_slope          38206 non-null  float64
#  5   stoch_slowk_3                  38199 non-null  float64
#  6   stoch_slowd_3                  38199 non-null  float64
#  7   stoch_slowk_3_slope            38198 non-null  float64
#  8   stoch_slowd_3_slope            38198 non-null  float64
#  9   stoch_slowk_6                  38179 non-null  float64
#  10  stoch_slowd_6                  38179 non-null  float64
#  11  stoch_slowk_6_slope            38178 non-null  float64
#  12  stoch_slowd_6_slope            38178 non-null  float64
#  13  williams_r_[14, 21, 28]        38203 non-null  float64
#  14  williams_r_[14, 21, 28]_slope  38202 non-null  float64
#  15  williams_r_[9, 16, 18]         38208 non-null  float64
#  16  williams_r_[9, 16, 18]_slope   38207 non-null  float64
#  17  cci_[14, 21, 28]               38203 non-null  float64
#  18  cci_[14, 21, 28]_slope         38202 non-null  float64
#  19  cci_[9, 16, 18]                38208 non-null  float64
#  20  cci_[9, 16, 18]_slope          38207 non-null  float64
#  21  momentum_[14, 21, 28]          38202 non-null  float64
#  22  momentum_[14, 21, 28]_slope    38201 non-null  float64
#  23  momentum_[9, 16, 18]           38207 non-null  float64
#  24  momentum_[9, 16, 18]_slope     38206 non-null  float64
#  25  momentum_[10, 14, 20]          38206 non-null  float64
#  26  momentum_[10, 14, 20]_slope    38205 non-null  float64
# dtypes: float64(27)
# memory usage: 8.2 MB
# None
# ==================================================
# Shape of data (38216, 27)
# ==================================================
# 0 rows removed
# ==================================================

# %%
momentum_signals = ForexRSISignals(
    data = momentum_data[0],  #we need to format first  
)
# Out:
# ==================================================
# RSI SIGNAL GENERATION
# ==================================================
# Available functions:
# 1 rsi_overbought_oversold_signals
# 2 rsi_centerline_signals
# 3 rsi_divergence_signals
# 4 rsi_momentum_signals
# 5 rsi_failure_swing_signals
# 6 rsi_trend_reversal_signals
# 7 generate_all_rsi_signals
# ==================================================
