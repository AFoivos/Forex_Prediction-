# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Dict, List, Optional, Union
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from plots import ForexPlotter

from data_handle import (
    ForexDataClean,
    ForexDataLoad,
    ForexPctChange,
    ForexQuickLook,
)

from features import (
    ForexTSIndicators,
    ForexCustomIndicators,
    ForexMomentumIndicators,
    ForexTrendIndicators,
    ForexVolatilityIndicators,
    ForexVolumeIndicators,
    ForexMASignals,
    ForexMACDSignals,
    ForexADXSignals,
    ForexParabolicSARSignals,
    ForexRSISignals,
    ForexStochasticSignals,
)

import warnings
warnings.filterwarnings('ignore')


data = ForexDataLoad(file_path = '../data/xauaud.csv').data
ohlcv_data = ForexDataLoad(file_path = '../data/xauaud.csv').data

cleaner = ForexDataClean(data = data, fast_clean = True)
data = cleaner.data
# Out:
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_dataframe
# 3 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_dataframe
# 3 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA CLEANER
# ==================================================
#  Available Fuctions
# 1 remove_duplicates
# 2 handle_missing_values
# 3 validate_ohlc_integrity
# 4 handle_outliers
# ==================================================
# ==================================================
# Keep = first and subset = None
# Removed 0 duplicate entries
# Found 1 missing values
#  dropped: 1 missing values .
# ==================================================
# OUTLIER DETECTION AND HANDLING
# ==================================================
# Method: quantile, Strategy: cap, Threshold: 3.0
# Remove outliers: False
# --------------------------------------------------
# open: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.81300 - 5218.90300]
# Original range: [1674.10000 - 5476.98000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# high: Found 764 outliers (381 low, 383 high)
# Bounds: [1819.15000 - 5224.87300]
# Original range: [1676.91000 - 5483.78000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# low: Found 766 outliers (383 low, 383 high)
# Bounds: [1816.29450 - 5211.65900]
# Original range: [1671.60000 - 5474.51000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# close: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.85250 - 5218.90300]
# Original range: [1672.21000 - 5477.23000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# volume: Found 48 outliers (0 low, 48 high)
# Bounds: [0.00000 - 0.00000]
# Original range: [0.00000 - 9910.00000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# ==================================================
# SUMMARY: Found 3110 outliers (not removed)
# Use remove=True to handle these outliers
# ==================================================
# ==================================================
# OHLC DATA INTEGRITY VALIDATION
# ==================================================
# No OHLC integrity violations found
# All OHLC values are consistent

# %%
momentum_data = ForexMomentumIndicators(data = data).generate_all_momentum_indicators(
    stochastic_periods = [[14, 3, 3], [28, 6, 6]],
    rsi_periods = [[14, 21, 28], [9, 16, 18]],
    williams_periods = [[14, 21, 28], [9, 16, 18]],
    momentum_periods = [[14, 21, 28], [9, 16, 18], [10, 14, 20]],
    cci_periods = [[14, 21, 28], [9, 16, 18]],
)
# Out:
# ==================================================
# MOMENTUM INDICATORS
# ==================================================
#  Available Fuctions
# 1 add_rsi
# 2 add_stochastic
# 3 add_williams_r
# 4 add_cci
# 5 add_momentum
# 6 generate_all_momentum_indicators
# ==================================================
# ==================================================
# Data Info
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38216 entries, 2017-04-24 02:00:00 to 2025-09-05 20:00:00
# Data columns (total 61 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   close                38216 non-null  float64
#  1   rsi_14               38202 non-null  float64
#  2   rsi_14_slope         38201 non-null  float64
#  3   rsi_21               38195 non-null  float64
#  4   rsi_21_slope         38194 non-null  float64
#  5   rsi_28               38188 non-null  float64
#  6   rsi_28_slope         38187 non-null  float64
#  7   rsi_9                38207 non-null  float64
#  8   rsi_9_slope          38206 non-null  float64
#  9   rsi_16               38200 non-null  float64
#  10  rsi_16_slope         38199 non-null  float64
#  11  rsi_18               38198 non-null  float64
#  12  rsi_18_slope         38197 non-null  float64
#  13  stoch_slowk_3        38199 non-null  float64
#  14  stoch_slowd_3        38199 non-null  float64
#  15  stoch_slowk_3_slope  38198 non-null  float64
#  16  stoch_slowd_3_slope  38198 non-null  float64
#  17  stoch_slowk_6        38179 non-null  float64
#  18  stoch_slowd_6        38179 non-null  float64
#  19  stoch_slowk_6_slope  38178 non-null  float64
#  20  stoch_slowd_6_slope  38178 non-null  float64
#  21  williams_r_14        38203 non-null  float64
#  22  williams_r_14_slope  38202 non-null  float64
#  23  williams_r_21        38196 non-null  float64
#  24  williams_r_21_slope  38195 non-null  float64
#  25  williams_r_28        38189 non-null  float64
#  26  williams_r_28_slope  38188 non-null  float64
#  27  williams_r_9         38208 non-null  float64
#  28  williams_r_9_slope   38207 non-null  float64
#  29  williams_r_16        38201 non-null  float64
#  30  williams_r_16_slope  38200 non-null  float64
#  31  williams_r_18        38199 non-null  float64
#  32  williams_r_18_slope  38198 non-null  float64
#  33  cci_14               38203 non-null  float64
#  34  cci_14_slope         38202 non-null  float64
#  35  cci_21               38196 non-null  float64
#  36  cci_21_slope         38195 non-null  float64
#  37  cci_28               38189 non-null  float64
#  38  cci_28_slope         38188 non-null  float64
#  39  cci_9                38208 non-null  float64
#  40  cci_9_slope          38207 non-null  float64
#  41  cci_16               38201 non-null  float64
#  42  cci_16_slope         38200 non-null  float64
#  43  cci_18               38199 non-null  float64
#  44  cci_18_slope         38198 non-null  float64
#  45  momentum_14          38202 non-null  float64
#  46  momentum_14_slope    38201 non-null  float64
#  47  momentum_21          38195 non-null  float64
#  48  momentum_21_slope    38194 non-null  float64
#  49  momentum_28          38188 non-null  float64
#  50  momentum_28_slope    38187 non-null  float64
#  51  momentum_9           38207 non-null  float64
#  52  momentum_9_slope     38206 non-null  float64
#  53  momentum_16          38200 non-null  float64
#  54  momentum_16_slope    38199 non-null  float64
#  55  momentum_18          38198 non-null  float64
#  56  momentum_18_slope    38197 non-null  float64
#  57  momentum_10          38206 non-null  float64
#  58  momentum_10_slope    38205 non-null  float64
#  59  momentum_20          38196 non-null  float64
#  60  momentum_20_slope    38195 non-null  float64
# dtypes: float64(61)
# memory usage: 18.1 MB
# None
# ==================================================
# Shape of data (38216, 61)
# ==================================================
# 0 rows removed
# ==================================================

# %%
stoch_signals = ForexStochasticSignals(
    data = momentum_data[0],
    parameters = momentum_data[1]['stochastic_params']
)
# Out:
# ==================================================
# STOCHASTIC SIGNAL GENERATION
# ==================================================
# Available functions:
# 1 stochastic_overbought_oversold_signals
# 2 stochastic_crossover_signals
# 3 stochastic_divergence_signals
# 4 stochastic_momentum_signals
# 5 stochastic_reversal_signals
# 6 generate_all_stochastic_signals
# ==================================================

# %%
momentum_signals_data = stoch_signals.generate_all_stochastic_signals()
# Out:
# ==================================================
# Data Info
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38216 entries, 2017-04-24 02:00:00 to 2025-09-05 20:00:00
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   close                                  38216 non-null  float64
#  1   stoch_slowk_3_overbough                38216 non-null  int64
#  2   stoch_slowk_6_overbough                38216 non-null  int64
#  3   stoch_slowk_3_stoch_slowd_3_crossover  38216 non-null  int64
#  4   stoch_slowk_3_stoch_slowd_6_crossover  38216 non-null  int64
#  5   stoch_slowk_6_stoch_slowd_3_crossover  38216 non-null  int64
#  6   stoch_slowk_6_stoch_slowd_6_crossover  38216 non-null  int64
#  7   stoch_slowk_3_divergence               38216 non-null  int64
#  8   stoch_slowk_6_divergence               38216 non-null  int64
#  9   stoch_slowk_3_momentum                 38216 non-null  int64
#  10  stoch_slowk_6_momentum                 38216 non-null  int64
#  11  stoch_slowd_3_momentum                 38216 non-null  int64
#  12  stoch_slowd_6_momentum                 38216 non-null  int64
#  13  stoch_slowk_3_reversal                 38216 non-null  int64
#  14  stoch_slowk_6_reversal                 38216 non-null  int64
# dtypes: float64(1), int64(14)
# memory usage: 4.7 MB
# None
# ==================================================
# Shape of data (38216, 15)
# ==================================================
# 0 rows removed
# ==================================================

# %%
plotter = ForexPlotter(data = momentum_signals_data)
plotter.plot_signals(periods = 240)
