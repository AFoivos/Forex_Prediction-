# %%
import os
import sys
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema
import numpy as np
import pandas as pd

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    
from data_handle import(
    ForexDataClean,
    ForexDataLoad,
)

from features import ForexFeauturesExtractor

from plots import ForexPlotter

import warnings
warnings.filterwarnings('ignore')

data = ForexDataLoad(file_path = '../data/xauaud.csv').data

cleaner = ForexDataClean(data = data)
data = cleaner.fast_cleaner()

features = ForexFeauturesExtractor(
    data = data
)

all_features, indicators_data, signals_data, extreme_data = features.extract_all_features()

# %%
signals_data.tail()
# Out:
#                        close  rsi_14_overbought  rsi_21_overbought  \
# datetime
# 2025-09-05 16:00:00  5455.01                  0                  0
# 2025-09-05 17:00:00  5474.64                  0                  0
# 2025-09-05 18:00:00  5468.49                  0                  0
# 2025-09-05 19:00:00  5476.84                  0                  0
# 2025-09-05 20:00:00  5477.23                  0                  0
#
#                      rsi_28_overbought  rsi_14_centerline  rsi_21_centerline  \
# datetime
# 2025-09-05 16:00:00                  0                  0                  0
# 2025-09-05 17:00:00                  0                  0                  0
# 2025-09-05 18:00:00                  0                  0                  0
# 2025-09-05 19:00:00                  0                  0                  0
# 2025-09-05 20:00:00                  0                  0                  0
#
#                      rsi_28_centerline  rsi_14_divergence  rsi_21_divergence  \
# datetime
# 2025-09-05 16:00:00                  0                  0                  0
# 2025-09-05 17:00:00                  0                  0                  0
# 2025-09-05 18:00:00                  0                  0                  0
# 2025-09-05 19:00:00                  0                  0                  0
# 2025-09-05 20:00:00                  0                  0                  0
#
#                      rsi_28_divergence  ...  std_dev_100_trend  \
# datetime                                ...
# 2025-09-05 16:00:00                  0  ...                  1
# 2025-09-05 17:00:00                  0  ...                  1
# 2025-09-05 18:00:00                  0  ...                  1
# 2025-09-05 19:00:00                  0  ...                  1
# 2025-09-05 20:00:00                  0  ...                  1
#
#                      std_dev_20_divergence  std_dev_50_divergence  \
# datetime
# 2025-09-05 16:00:00                      0                      1
# 2025-09-05 17:00:00                      0                      0
# 2025-09-05 18:00:00                      0                      0
# 2025-09-05 19:00:00                      0                      0
# 2025-09-05 20:00:00                      0                      0
#
#                      std_dev_100_divergence  std_dev_20_mean_reversion  \
# datetime
# 2025-09-05 16:00:00                       1                          0
# 2025-09-05 17:00:00                       1                          2
# 2025-09-05 18:00:00                       1                          0
# 2025-09-05 19:00:00                       1                          2
# 2025-09-05 20:00:00                       1                          0
#
#                      std_dev_50_mean_reversion  std_dev_100_mean_reversion  \
# datetime
# 2025-09-05 16:00:00                          0                           0
# 2025-09-05 17:00:00                          2                           0
# 2025-09-05 18:00:00                          2                           0
# 2025-09-05 19:00:00                          2                           0
# 2025-09-05 20:00:00                          2                           0
#
#                      std_dev_20_vol_cluster  std_dev_50_vol_cluster  \
# datetime
# 2025-09-05 16:00:00                       0                       0
# 2025-09-05 17:00:00                       0                       0
# 2025-09-05 18:00:00                       0                       0
# 2025-09-05 19:00:00                       0                       0
# 2025-09-05 20:00:00                       0                       0
#
#                      std_dev_100_vol_cluster
# datetime
# 2025-09-05 16:00:00                        0
# 2025-09-05 17:00:00                        0
# 2025-09-05 18:00:00                        0
# 2025-09-05 19:00:00                        0
# 2025-09-05 20:00:00                        0
#
# [5 rows x 273 columns]

# %%
trend_signals = [
    'adx_14_trend_strength',
    'adx_21_trend_strength',
    'adx_28_trend_strength',
    
]

# %%
for name in trend_signals:
    if

# %%
signals_data.columns.tolist()
# Out:
# ['close',
#  'rsi_14_overbought',
#  'rsi_21_overbought',
#  'rsi_28_overbought',
#  'rsi_14_centerline',
#  'rsi_21_centerline',
#  'rsi_28_centerline',
#  'rsi_14_divergence',
#  'rsi_21_divergence',
#  'rsi_28_divergence',
#  'rsi_14_slope_momentum',
#  'rsi_21_slope_momentum',
#  'rsi_28_slope_momentum',
#  'rsi_14_swing_fail',
#  'rsi_21_swing_fail',
#  'rsi_28_swing_fail',
#  'rsi_14_reversal',
#  'rsi_21_reversal',
#  'rsi_28_reversal',
#  'stoch_slowk_3_overbough',
#  'stoch_slowk_3_stoch_slowd_3_crossover',
#  'stoch_slowk_3_divergence',
#  'stoch_slowk_3_momentum',
#  'stoch_slowd_3_momentum',
#  'stoch_slowk_3_reversal',
#  'williams_r_14_overbought_oversold',
#  'williams_r_21_overbought_oversold',
#  'williams_r_28_overbought_oversold',
#  'williams_r_14_slope_momentum',
#  'williams_r_21_slope_momentum',
#  'williams_r_28_slope_momentum',
#  'williams_r_14_reversal',
#  'williams_r_21_reversal',
#  'williams_r_28_reversal',
#  'williams_r_14_divergence',
#  'williams_r_21_divergence',
#  'williams_r_28_divergence',
#  'williams_r_14_extreme',
#  'williams_r_21_extreme',
#  'williams_r_28_extreme',
#  'cci_14_overbought_oversold',
#  'cci_21_overbought_oversold',
#  'cci_28_overbought_oversold',
#  'cci_14_slope_momentum',
#  'cci_21_slope_momentum',
#  'cci_28_slope_momentum',
#  'cci_14_reversal',
#  'cci_21_reversal',
#  'cci_28_reversal',
#  'cci_14_divergence',
#  'cci_21_divergence',
#  'cci_28_divergence',
#  'cci_14_zero_cross',
#  'cci_21_zero_cross',
#  'cci_28_zero_cross',
#  'cci_14_extreme',
#  'cci_21_extreme',
#  'cci_28_extreme',
#  'momentum_10_direction',
#  'momentum_14_direction',
#  'momentum_20_direction',
#  'momentum_10_slope_acceleration',
#  'momentum_14_slope_acceleration',
#  'momentum_20_slope_acceleration',
#  'momentum_10_zero_cross',
#  'momentum_14_zero_cross',
#  'momentum_20_zero_cross',
#  'momentum_10_divergence',
#  'momentum_14_divergence',
#  'momentum_20_divergence',
#  'momentum_10_extreme',
#  'momentum_14_extreme',
#  'momentum_20_extreme',
#  'momentum_10_trend_strength',
#  'momentum_14_trend_strength',
#  'momentum_20_trend_strength',
#  'sma_10_sma_20_golden_death_cross',
#  'sma_10_sma_50_golden_death_cross',
#  'sma_10_sma_100_golden_death_cross',
#  'sma_10_sma_200_golden_death_cross',
#  'sma_20_sma_50_golden_death_cross',
#  'sma_20_sma_100_golden_death_cross',
#  'sma_20_sma_200_golden_death_cross',
#  'sma_50_sma_100_golden_death_cross',
#  'sma_50_sma_200_golden_death_cross',
#  'sma_100_sma_200_golden_death_cross',
#  'ema_10_ema_20_crossover',
#  'ema_10_ema_50_crossover',
#  'ema_10_ema_100_crossover',
#  'ema_10_ema_200_crossover',
#  'ema_20_ema_50_crossover',
#  'ema_20_ema_100_crossover',
#  'ema_20_ema_200_crossover',
#  'ema_50_ema_100_crossover',
#  'ema_50_ema_200_crossover',
#  'ema_100_ema_200_crossover',
#  'ema_10_ema_20_ema_50_hierarchy',
#  'ema_10_ema_20_ema_100_hierarchy',
#  'ema_10_ema_20_ema_200_hierarchy',
#  'ema_10_ema_50_ema_100_hierarchy',
#  'ema_10_ema_50_ema_200_hierarchy',
#  'ema_10_ema_100_ema_200_hierarchy',
#  'ema_20_ema_50_ema_100_hierarchy',
#  'ema_20_ema_50_ema_200_hierarchy',
#  'ema_20_ema_100_ema_200_hierarchy',
#  'ema_50_ema_100_ema_200_hierarchy',
#  'sma_10_sma_20_sma_50_hierarchy',
#  'sma_10_sma_20_sma_100_hierarchy',
#  'sma_10_sma_20_sma_200_hierarchy',
#  'sma_10_sma_50_sma_100_hierarchy',
#  'sma_10_sma_50_sma_200_hierarchy',
#  'sma_10_sma_100_sma_200_hierarchy',
#  'sma_20_sma_50_sma_100_hierarchy',
#  'sma_20_sma_50_sma_200_hierarchy',
#  'sma_20_sma_100_sma_200_hierarchy',
#  'sma_50_sma_100_sma_200_hierarchy',
#  'ema_10_bounce',
#  'ema_10_slope_direction',
#  'ema_10_slope_acceleration',
#  'ema_10_trend_strong',
#  'ema_20_slope_direction',
#  'ema_20_slope_acceleration',
#  'ema_20_trend_strong',
#  'ema_50_slope_direction',
#  'ema_50_slope_acceleration',
#  'ema_50_trend_strong',
#  'ema_100_slope_direction',
#  'ema_100_slope_acceleration',
#  'ema_100_trend_strong',
#  'ema_200_slope_direction',
#  'ema_200_slope_acceleration',
#  'ema_200_trend_strong',
#  'sma_10_slope_direction',
#  'sma_10_slope_acceleration',
#  'sma_10_trend_strong',
#  'sma_20_slope_direction',
#  'sma_20_slope_acceleration',
#  'sma_20_trend_strong',
#  'sma_50_slope_direction',
#  'sma_50_slope_acceleration',
#  'sma_50_trend_strong',
#  'sma_100_slope_direction',
#  'sma_100_slope_acceleration',
#  'sma_100_trend_strong',
#  'sma_200_slope_direction',
#  'sma_200_slope_acceleration',
#  'sma_200_trend_strong',
#  'ema_10_overbought_oversold',
#  'ema_20_overbought_oversold',
#  'ema_50_overbought_oversold',
#  'ema_100_overbought_oversold',
#  'ema_200_overbought_oversold',
#  'sma_10_overbought_oversold',
#  'sma_20_overbought_oversold',
#  'sma_50_overbought_oversold',
#  'sma_100_overbought_oversold',
#  'sma_200_overbought_oversold',
#  'macd_12_26_macd_signal_9_crossover',
#  'macd_hist_fast_12_slow26_sig9_direction',
#  'macd_hist_fast_12_slow26_sig9_momentum',
#  'macd_12_26_zero_cross',
#  'adx_14_trend_strength',
#  'adx_21_trend_strength',
#  'adx_28_trend_strength',
#  'adx_14_plus_adx_14_minus_direction',
#  'adx_14_plus_adx_21_minus_direction',
#  'adx_14_plus_adx_28_minus_direction',
#  'adx_21_plus_adx_14_minus_direction',
#  'adx_21_plus_adx_21_minus_direction',
#  'adx_21_plus_adx_28_minus_direction',
#  'adx_28_plus_adx_14_minus_direction',
#  'adx_28_plus_adx_21_minus_direction',
#  'adx_28_plus_adx_28_minus_direction',
#  'adx_14_plus_adx_14_minus_crossover',
#  'adx_14_plus_adx_21_minus_crossover',
#  'adx_14_plus_adx_28_minus_crossover',
#  'adx_21_plus_adx_14_minus_crossover',
#  'adx_21_plus_adx_21_minus_crossover',
#  'adx_21_plus_adx_28_minus_crossover',
#  'adx_28_plus_adx_14_minus_crossover',
#  'adx_28_plus_adx_21_minus_crossover',
#  'adx_28_plus_adx_28_minus_crossover',
#  'adx_14_slope_slope',
#  'adx_21_slope_slope',
#  'adx_28_slope_slope',
#  'adx_14_adx_14_plus_adx_14_minus_comprehensive',
#  'adx_14_adx_14_plus_adx_21_minus_comprehensive',
#  'adx_14_adx_14_plus_adx_28_minus_comprehensive',
#  'adx_14_adx_21_plus_adx_14_minus_comprehensive',
#  'adx_14_adx_21_plus_adx_21_minus_comprehensive',
#  'adx_14_adx_21_plus_adx_28_minus_comprehensive',
#  'adx_14_adx_28_plus_adx_14_minus_comprehensive',
#  'adx_14_adx_28_plus_adx_21_minus_comprehensive',
#  'adx_14_adx_28_plus_adx_28_minus_comprehensive',
#  'adx_21_adx_14_plus_adx_14_minus_comprehensive',
#  'adx_21_adx_14_plus_adx_21_minus_comprehensive',
#  'adx_21_adx_14_plus_adx_28_minus_comprehensive',
#  'adx_21_adx_21_plus_adx_14_minus_comprehensive',
#  'adx_21_adx_21_plus_adx_21_minus_comprehensive',
#  'adx_21_adx_21_plus_adx_28_minus_comprehensive',
#  'adx_21_adx_28_plus_adx_14_minus_comprehensive',
#  'adx_21_adx_28_plus_adx_21_minus_comprehensive',
#  'adx_21_adx_28_plus_adx_28_minus_comprehensive',
#  'adx_28_adx_14_plus_adx_14_minus_comprehensive',
#  'adx_28_adx_14_plus_adx_21_minus_comprehensive',
#  'adx_28_adx_14_plus_adx_28_minus_comprehensive',
#  'adx_28_adx_21_plus_adx_14_minus_comprehensive',
#  'adx_28_adx_21_plus_adx_21_minus_comprehensive',
#  'adx_28_adx_21_plus_adx_28_minus_comprehensive',
#  'adx_28_adx_28_plus_adx_14_minus_comprehensive',
#  'adx_28_adx_28_plus_adx_21_minus_comprehensive',
#  'adx_28_adx_28_plus_adx_28_minus_comprehensive',
#  'sar_0.02_0.2_trend',
#  'sar_0.02_0.2_reversal',
#  'sar_0.02_0.2_distance',
#  'sar_0.02_0.2_slope_signal',
#  'sar_0.02_0.2_trend_confirmation',
#  'atr_14_volatility_level',
#  'atr_21_volatility_level',
#  'atr_28_volatility_level',
#  'atr_14_breakout',
#  'atr_21_breakout',
#  'atr_28_breakout',
#  'atr_14_slope_trend_strength',
#  'atr_21_slope_trend_strength',
#  'atr_28_slope_trend_strength',
#  'atr_14_squeeze',
#  'atr_21_squeeze',
#  'atr_28_squeeze',
#  'atr_14_slope_expansion',
#  'atr_21_slope_expansion',
#  'atr_28_slope_expansion',
#  'atr_14_sr_break',
#  'atr_21_sr_break',
#  'atr_28_sr_break',
#  'bb_20_2.0_2.0_above_below',
#  'bb_20_2.0_2.0_wide_narrow',
#  'bb_20_2.0_2.0_squeeze_expansion',
#  'bb_20_2.0_2.0_breakout',
#  'bb_20_2.0_2.0_upper_lower_half',
#  'bb_20_2.0_2.0_bullish_bearish',
#  'bb_20_2.0_2.0_upper_lower_walking',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_position',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_breakout',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_keltner_ema_20_atr_10_2.0_middle_squeeze',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_keltner_ema_20_atr_10_2.0_middle_trend',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_divergence',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_walk',
#  'keltner_ema_20_atr_10_2.0_upper_keltner_ema_20_atr_10_2.0_lower_keltner_ema_20_atr_10_2.0_middle_reversal',
#  'std_dev_20_regime',
#  'std_dev_50_regime',
#  'std_dev_100_regime',
#  'std_dev_20_price_position',
#  'std_dev_50_price_position',
#  'std_dev_100_price_position',
#  'std_dev_20_breakout',
#  'std_dev_50_breakout',
#  'std_dev_100_breakout',
#  'std_dev_20_squeeze',
#  'std_dev_50_squeeze',
#  'std_dev_100_squeeze',
#  'std_dev_20_trend',
#  'std_dev_50_trend',
#  'std_dev_100_trend',
#  'std_dev_20_divergence',
#  'std_dev_50_divergence',
#  'std_dev_100_divergence',
#  'std_dev_20_mean_reversion',
#  'std_dev_50_mean_reversion',
#  'std_dev_100_mean_reversion',
#  'std_dev_20_vol_cluster',
#  'std_dev_50_vol_cluster',
#  'std_dev_100_vol_cluster']
