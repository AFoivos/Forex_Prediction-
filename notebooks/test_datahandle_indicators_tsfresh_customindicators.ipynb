# %%
import pandas as pd
import numpy as np
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from data_handle import (
    ForexDataClean,
    ForexDataLoad,
    ForexPctChange,
    ForexQuickLook,
)

from features import (
    ForexCustomFeatures,
    ForexMomentumIndicators,
    ForexTrendIndicators,
    ForexTSFeatures,
    ForexVolatilityIndicators,
    ForexVolumeIndicators,
)

import warnings
warnings.filterwarnings('ignore')

# %%
df = ForexDataLoad(file_path = '../data/xauaud.csv').data
# Out:
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_dataframe
# 3 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================

# %%
quick_look = ForexQuickLook( data = df, full_look = True, periods = 48)
# Out:
# ==================================================
# FOREX QUICK LOOK
# ==================================================
#  Available Fuctions
# 1 display_info
# 2 check_missing_values_and_duplicates
# 3 plot_candlestick
# 4 plot_time_series
# 5 get_summary
# ==================================================
# DATASET INFORMATION
# ==================================================
#
# 1. BASIC INFO:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2025-09-03 19:00:00 to 2025-09-05 20:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    48 non-null     float64
#  1   high    48 non-null     float64
#  2   low     48 non-null     float64
#  3   close   48 non-null     float64
#  4   volume  48 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.2 KB
# None
# ==================================================
#
# 2. FIRST 3 ROWS:
#                         open     high      low    close  volume
# datetime
# 2025-09-03 19:00:00  5441.48  5452.88  5439.54  5452.58       0
# 2025-09-03 20:00:00  5452.56  5462.86  5447.80  5461.05       0
# 2025-09-03 21:00:00  5461.05  5465.36  5446.87  5454.38       0
# ==================================================
#
# 3. LAST 3 ROWS:
#                         open     high      low    close  volume
# datetime
# 2025-09-05 18:00:00  5474.54  5477.82  5459.37  5468.49       0
# 2025-09-05 19:00:00  5468.33  5483.78  5466.57  5476.84       0
# 2025-09-05 20:00:00  5476.98  5479.45  5474.51  5477.23       0
# ==================================================
#
# 4. STATISTICAL DESCRIPTION:
#               open         high          low        close  volume
# count    48.000000    48.000000    48.000000    48.000000    48.0
# mean   5438.725417  5446.485000  5430.663333  5439.582500     0.0
# std      16.712627    16.845833    18.298108    17.595281     0.0
# min    5400.600000  5403.360000  5371.590000  5400.600000     0.0
# 25%    5428.125000  5435.802500  5422.315000  5428.132500     0.0
# 50%    5440.085000  5447.770000  5431.140000  5440.635000     0.0
# 75%    5447.782500  5454.600000  5440.407500  5447.977500     0.0
# max    5476.980000  5483.780000  5474.510000  5477.230000     0.0
# ==================================================
#
# 6. DATA TYPES:
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# dtype: object
# ==================================================
#
# 7. INDEX INFORMATION:
# Index name: datetime
# Index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# ==================================================
# MISSING VALUES ANALYSIS
# ==================================================
#
# 1. NaN VALUES PER COLUMN:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ==================================================
#
# 2. DUPLICATE ROWS: 0
# ==================================================
#
# 3. MISSING VALUES PER COLUMN:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ==================================================
#
# 4. TOTAL MISSING VALUES: 0
# ==================================================
#
# 5. MISSING VALUES PERCENTAGE:
# open      0.0
# high      0.0
# low       0.0
# close     0.0
# volume    0.0
# dtype: float64
# ==================================================
#
# 6. INFINITE VALUES:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
# ==================================================
# DATASET SUMMARY
# ==================================================
# Total Rows: 48
# Total Columns: 5
# Date Range: 2025-09-03 19:00:00 to 2025-09-05 20:00:00
# Numeric Columns: ['open', 'high', 'low', 'close', 'volume']
# Non Numeric Columns: []
# Missing Values: 0
# Duplicates: 0
# Columns: Index(['open', 'high', 'low', 'close', 'volume'], dtype='object')
# Index Column: datetime
# ==================================================

# %%
cleaner = ForexDataClean(data = df, fast_clean = True)
df = cleaner.data
# Out:
# ==================================================
# FOREX DATA CLEANER
# ==================================================
#  Available Fuctions
# 1 remove_duplicates
# 2 handle_missing_values
# 3 validate_ohlc_integrity
# 4 handle_outliers
# ==================================================
# ==================================================
# Keep = first and subset = None
# Removed 0 duplicate entries
# Found 1 missing values
#  dropped: 1 missing values .
# ==================================================
# OUTLIER DETECTION AND HANDLING
# ==================================================
# Method: quantile, Strategy: cap, Threshold: 3.0
# Remove outliers: False
# --------------------------------------------------
# open: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.81300 - 5218.90300]
# Original range: [1674.10000 - 5476.98000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# high: Found 764 outliers (381 low, 383 high)
# Bounds: [1819.15000 - 5224.87300]
# Original range: [1676.91000 - 5483.78000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# low: Found 766 outliers (383 low, 383 high)
# Bounds: [1816.29450 - 5211.65900]
# Original range: [1671.60000 - 5474.51000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# close: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.85250 - 5218.90300]
# Original range: [1672.21000 - 5477.23000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# volume: Found 48 outliers (0 low, 48 high)
# Bounds: [0.00000 - 0.00000]
# Original range: [0.00000 - 9910.00000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# ==================================================
# SUMMARY: Found 3110 outliers (not removed)
# Use remove=True to handle these outliers
# ==================================================
# ==================================================
# OHLC DATA INTEGRITY VALIDATION
# ==================================================
# No OHLC integrity violations found
# All OHLC values are consistent

# %%
df
# Out:
#                         open     high      low    close  volume
# datetime
# 2017-04-24 02:00:00  1686.03  1686.15  1681.30  1682.15    4146
# 2017-04-24 03:00:00  1682.11  1691.44  1681.90  1689.13    4329
# 2017-04-24 04:00:00  1689.09  1689.24  1685.89  1687.68    2609
# 2017-04-24 05:00:00  1687.65  1688.84  1686.15  1688.36    1592
# 2017-04-24 06:00:00  1688.34  1689.59  1686.91  1687.06    1275
# ...                      ...      ...      ...      ...     ...
# 2025-09-05 16:00:00  5447.51  5456.26  5433.22  5455.01       0
# 2025-09-05 17:00:00  5454.84  5474.80  5451.73  5474.64       0
# 2025-09-05 18:00:00  5474.54  5477.82  5459.37  5468.49       0
# 2025-09-05 19:00:00  5468.33  5483.78  5466.57  5476.84       0
# 2025-09-05 20:00:00  5476.98  5479.45  5474.51  5477.23       0
#
# [38216 rows x 5 columns]

# %%
trends = ForexTrendIndicators(data = df).get_all_trend_indicators()
trends.dropna()
# Out:
# ==================================================
# TREND INDICATORS
# ==================================================
#  Available Fuctions:
# 1 add_sma
# 2 add_ema
# 3 add_macd
# 4 add_adx
# 5 add_parabolic_sar
# 6 add_trend_confirmation
# ==================================================
#                         open     high      low    close  volume  trend_sma_20  \
# datetime
# 2019-03-25 08:00:00  1858.30  1859.15  1858.02  1858.37       0     1853.9015
# 2019-03-25 09:00:00  1858.37  1859.40  1857.13  1857.96       0     1854.2200
# 2019-03-25 10:00:00  1857.96  1860.14  1856.84  1858.41       0     1854.6340
# 2019-03-25 10:00:00             -0.980706  51.414961      28.240650
# 2019-03-25 11:00:00             -0.993085  50.914978      26.803418
# 2019-03-25 12:00:00             -1.053223  50.320507      25.416446
# ...                                   ...        ...            ...
# 2025-09-05 16:00:00              0.533637  15.971064      26.705218
# 2025-09-05 17:00:00              2.647860  17.384413      32.077099
# 2025-09-05 18:00:00              3.425802  18.829879      30.830188
# 2025-09-05 19:00:00              4.242956  20.430768      31.110880
# 2025-09-05 20:00:00              4.524192  21.917309      30.416511
#
#                      trend_minus_di  trend_parabolic_sar
# datetime
# 2019-03-25 08:00:00        8.632179          1856.309360
# 2019-03-25 09:00:00       10.127695          1861.030000
# 2019-03-25 10:00:00        9.407310          1860.952000
# 2019-03-25 11:00:00       10.316522          1860.787520
# 2019-03-25 12:00:00       10.232649          1860.512869
# ...                             ...                  ...
# 2025-09-05 16:00:00       16.867883          5416.314800
# 2025-09-05 17:00:00       15.179211          5417.328904
# 2025-09-05 18:00:00       13.974317          5419.627748
# 2025-09-05 19:00:00       12.942315          5423.119283
# 2025-09-05 20:00:00       12.653453          5427.972140
#
# [38116 rows x 22 columns]

# %%
momentum = ForexMomentumIndicators(data = df)
# Out:
# ==================================================
# MOMENTUM INDICATORS
# ==================================================
#  Available Fuctions
# 1 add_rsi
# 2 add_stochastic
# 3 add_williams_r
# 4 add_cci
# 5 add_momentum
# 6 get_all_momentum_indicators
# ==================================================

# %%
momentum.get_all_momentum_indicators().tail(10)
# Out:
#                         open     high      low    close  volume  momen_rsi_14  \
# datetime
# 2025-09-05 11:00:00  5421.73  5425.39  5415.28  5417.88       0     39.924414
# 2025-09-05 12:00:00  5417.88  5429.94  5417.73  5427.42       0     45.864889
# 2025-09-05 13:00:00  5427.42  5428.38  5421.64  5427.78       0     46.081560
# 2025-09-05 14:00:00  5427.78  5431.89  5422.54  5431.70       0     48.498726
# 2025-09-05 15:00:00  5431.90  5467.02  5422.86  5447.40       0     56.843485
# 2025-09-05 16:00:00  5447.51  5456.26  5433.22  5455.01       0     60.208992
# 2025-09-05 17:00:00  5454.84  5474.80  5451.73  5474.64       0     67.294154
# 2025-09-05 18:00:00  5474.54  5477.82  5459.37  5468.49       0     63.480472
# 2025-09-05 19:00:00  5468.33  5483.78  5466.57  5476.84       0     66.275040
# 2025-09-05 20:00:00  5476.98  5479.45  5474.51  5477.23       0     66.404351
#
#                      momen_rsi_14_trend  momen_rsi_21  momen_rsi_21_trend  \
# datetime
# 2025-09-05 11:00:00           -1.763241     45.570117           -1.312349
# 2025-09-05 12:00:00            5.940475     49.169326            3.599209
# 2025-09-05 13:00:00            0.216670     49.302158            0.132832
# 2025-09-05 14:00:00            2.417166     50.772957            1.470799
# 2025-09-05 15:00:00            8.344759     56.125706            5.352749
# 2025-09-05 16:00:00            3.365507     58.426432            2.300725
# 2025-09-05 17:00:00            7.085162     63.596775            5.170344
# 2025-09-05 18:00:00           -3.813682     61.097193           -2.499583
# 2025-09-05 19:00:00            2.794568     63.161323            2.064130
# 2025-09-05 20:00:00            0.129311     63.256932            0.095609
#
#                      momen_rsi_28  momen_rsi_28_trend  momen_stoch_slowk  \
# 2025-09-05 14:00:00       10.122387       14.017003        54.256884
# 2025-09-05 15:00:00        9.602899       14.059145        53.994257
# 2025-09-05 16:00:00        9.501006       13.886057        53.575516
# 2025-09-05 17:00:00       12.304267       14.742737        53.428630
# 2025-09-05 18:00:00       13.734463       15.324239        53.194591
# 2025-09-05 19:00:00       15.728269       16.202972        53.074741
# 2025-09-05 20:00:00       17.332776       17.065102        52.827657
#
# [10 rows x 39 columns]

# %%
volume = ForexVolumeIndicators(data = df)
# Out:
# ==================================================
# VOLUME INDICATORS
# ==================================================
#  Available Fuctions
# 1 add_obv
# 2 add_volume_sma
# 3 add_volume_roc
# 4 get_all_volume_indicators
# ==================================================

# %%
volume.get_all_volume_indicators().tail(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'obv'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 volume.get_all_volume_indicators().tail(10)
#
# File ~/Documents/Projects/Forex_Prediction-/features/indicators/volume.py:130, in ForexVolumeIndicators.get_all_volume_indicators(self, volume_sma_periods, volume_roc_periods)
#     115 def get_all_volume_indicators(
#     116     self,
#     117     volume_sma_periods: List[int] = [5, 10, 20, 50],
#     118     volume_roc_periods: List[int] = [5, 10, 14, 21],
#     119 ):
#     121     """
#     122     Adds all volume indicators
#     123
#    (...)
#     127
#     128     """
# --> 130     self.add_obv()
#     131     self.add_volume_sma(volume_sma_periods)
#     132     self.add_volume_roc(volume_roc_periods)
#
# File ~/Documents/Projects/Forex_Prediction-/features/indicators/volume.py:64, in ForexVolumeIndicators.add_obv(self)
#      62 # OBV to moving average ratio
#      63 if len(self.data) > 20:
# ---> 64     obv_ma = self.data['obv'].rolling(window=20).mean()
#      65     self.data['volu_obv_ma_ratio'] = self.data['obv'] / obv_ma
#      67 return self.data
#
# File /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'obv'

# %%
x = volume.data.shape[0]

# %%
x
# Out:
# 38216

# %%
y = volume.data.dropna().shape[0]

# %%
y
# Out:
# 3

# %%
df[df['volume'] == 0].shape
# Out:
# (38168, 5)

# %%
#Problem with volume from MT5 data

# %%
custom = ForexCustomFeatures(data = df)
# Out:
# ==================================================
# CUSTOM FEATURES
# ==================================================
#  Available Functions:
# 1 add_returns_features
# 2 add_volatility_measures
# 3 add_price_position_features
# 4 add_seasonality_features
# 5 add_time_based_features
# 6 add_custom_derived_features
# 7 get_all_custom_features
# ==================================================

# %%
custom.get_all_custom_features().tail(10)
# Out:
#                         open     high      low    close  volume  return_1  \
# datetime
# 2025-09-05 11:00:00  5421.73  5425.39  5415.28  5417.88       0 -0.000730
# 2025-09-05 12:00:00  5417.88  5429.94  5417.73  5427.42       0  0.001761
# 2025-09-05 13:00:00  5427.42  5428.38  5421.64  5427.78       0  0.000066
# 2025-09-05 14:00:00  5427.78  5431.89  5422.54  5431.70       0  0.000722
# 2025-09-05 15:00:00  5431.90  5467.02  5422.86  5447.40       0  0.002890
# 2025-09-05 16:00:00  5447.51  5456.26  5433.22  5455.01       0  0.001397
# 2025-09-05 17:00:00  5454.84  5474.80  5451.73  5474.64       0  0.003599
# 2025-09-05 18:00:00  5474.54  5477.82  5459.37  5468.49       0 -0.001123
# 2025-09-05 19:00:00  5468.33  5483.78  5466.57  5476.84       0  0.001527
# 2025-09-05 20:00:00  5476.98  5479.45  5474.51  5477.23       0  0.000071
#
#                      log_return_1  return_vol_1  return_direction_1  return_5  \
# datetime
# 2025-09-05 11:00:00     -0.000731           NaN                  -1 -0.005479
# 2025-09-05 12:00:00      0.001759           NaN                   1 -0.004302
# 2025-09-05 13:00:00      0.000066           NaN                   1 -0.002712
# 2025-09-05 14:00:00      0.000722           NaN                   1 -0.001085
# 2025-09-05 15:00:00      0.002886           NaN                   1  0.004714
# 2025-09-05 16:00:00      0.001396           NaN                   1  0.006853
# 2025-09-05 17:00:00      0.003592           NaN                   1  0.008700
# 2025-09-05 18:00:00     -0.001124           NaN                  -1  0.007500
# 2025-09-05 19:00:00      0.001526           NaN                   1  0.008310
# 2025-09-05 20:00:00      0.000071           NaN                   1  0.005476
#
#                      ...  season  minutes_since_monday_open  period_of_day  \
# datetime             ...
# 2025-09-05 11:00:00  ...  summer                       6420        morning
# 2025-09-05 12:00:00  ...  summer                       6480        morning
# 2025-09-05 13:00:00  ...  summer                       6540      afternoon
# 2025-09-05 14:00:00  ...  summer                       6600      afternoon
# 2025-09-05 15:00:00  ...  summer                       6660      afternoon
# 2025-09-05 16:00:00  ...  summer                       6720      afternoon
# 2025-09-05 17:00:00  ...  summer                       6780        evening
# 2025-09-05 18:00:00  ...  summer                       6840        evening
# 2025-09-05 19:00:00  ...  summer                       6900        evening
# 2025-09-05 20:00:00  ...  summer                       6960        evening
#
#                      days_to_month_end  days_to_quarter_end  \
# datetime
# 2025-09-05 11:00:00                 25                   25
# 2025-09-05 12:00:00                 25                   25
# 2025-09-05 13:00:00                 25                   25
# 2025-09-05 14:00:00                 25                   25
# 2025-09-05 15:00:00                 25                   25
# 2025-09-05 16:00:00                 25                   25
# 2025-09-05 17:00:00                 25                   25
# 2025-09-05 18:00:00                 25                   25
# 2025-09-05 19:00:00                 25                   25
# 2025-09-05 20:00:00                 25                   25
#
#                      price_acceleration  momentum_ratio  \
# datetime
# 2025-09-05 11:00:00           -0.002909        2.132015
# 2025-09-05 12:00:00           -0.000834        1.240359
# 2025-09-05 13:00:00           -0.000108        1.041524
# 2025-09-05 14:00:00            0.000424        0.718941
# 2025-09-05 15:00:00            0.002936        2.650973
# 2025-09-05 16:00:00            0.005517        5.128374
# 2025-09-05 17:00:00            0.004339        1.995121
# 2025-09-05 18:00:00            0.002732        1.573052
# 2025-09-05 19:00:00            0.001094        1.151606
# 2025-09-05 20:00:00           -0.004740        0.536018
#
#                      vol_normalized_return  range_expansion  range_contraction
# datetime
# 2025-09-05 11:00:00              -0.031354                0                  0
# 2025-09-05 12:00:00               0.072457                0                  0
# 2025-09-05 13:00:00               0.002749                0                  0
# 2025-09-05 14:00:00               0.031670                0                  0
# 2025-09-05 15:00:00               0.117057                1                  0
# 2025-09-05 16:00:00               0.055355                1                  0
# 2025-09-05 17:00:00               0.136643                1                  0
# 2025-09-05 18:00:00              -0.041902                0                  0
# 2025-09-05 19:00:00               0.056125                0                  0
# 2025-09-05 20:00:00               0.002680                0                  1
#
# [10 rows x 74 columns]

# %%
ts_features = ForexTSFeatures(data = trends.tail(48), target_column = 'close' )
# Out:
# ==================================================
# TSFRESH FEATURE ENGINEERING
# ==================================================
#  Available Functions:
# 1 prepare_ts_data
# 2 extract_ts_features
# 3 select_relevant_features
# 4 get_feature_importance
# 5 get_train_test_split
# 6 get_all_features
# ==================================================

# %%
X_train, X_test, y_train, y_test = ts_features.get_all_features()
# Out:
# Rolling:   0%|          | 0/16 [00:00<?, ?it/s]/opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# Rolling: 100%|██████████| 16/16 [00:01<00:00, 10.40it/s]
# Using comprehensive feature settings
# Feature Extraction: 100%|██████████| 798/798 [00:12<00:00, 62.43it/s]
# Selecting relevant features...
# Aligned data: 38 samples
# Target range: 5400.6000 to 5461.0500
# X index: [Timestamp('2025-09-03 19:00:00'), Timestamp('2025-09-03 20:00:00'), Timestamp('2025-09-03 21:00:00'), Timestamp('2025-09-03 22:00:00'), Timestamp('2025-09-03 23:00:00')]
# y index: [Timestamp('2025-09-03 19:00:00'), Timestamp('2025-09-03 20:00:00'), Timestamp('2025-09-03 21:00:00'), Timestamp('2025-09-03 22:00:00'), Timestamp('2025-09-03 23:00:00')]
# Indices match: True
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# /opt/anaconda3/envs/dpenv/lib/python3.10/site-packages/dask/dataframe/_pyarrow_compat.py:23: UserWarning: You are using pyarrow version 8.0.0 which is known to be insecure. See https://www.cve.org/CVERecord?id=CVE-2023-47248 for further details. Please upgrade to pyarrow>=14.0.1 or install pyarrow-hotfix to patch your current version.
#   warnings.warn(
# Selected 381 relevant features
#  Top feature correlations:
#    1. tsfresh_ema_12__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6: 0.8633 (-)
#    2. tsfresh_macd_line__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2: 0.8260 (-)
#    3. tsfresh_ema_12__skewness: 0.8197 (-)
#    4. tsfresh_ema_12__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6: 0.8144 (-)
#    5. tsfresh_ema_12__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6: 0.8116 (-)
#    6. tsfresh_macd_signal__ratio_beyond_r_sigma__r_1: 0.8053 (-)
#    7. tsfresh_sma_50_slope__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20): 0.7932 (-)
#    8. tsfresh_macd_line__partial_autocorrelation__lag_2: 0.7927 (+)
#    9. tsfresh_parabolic_sar__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"mean": 0.7900 (+)
#   10. tsfresh_high__fourier_entropy__bins_5: 0.7898 (-)
#   11. tsfresh_sma_50_slope__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean": 0.7869 (-)
#   12. tsfresh_parabolic_sar__linear_trend__attr_"intercept": 0.7832 (-)
#   13. tsfresh_sma_50_slope__fft_coefficient__attr_"angle"__coeff_1: 0.7831 (-)
#   14. tsfresh_parabolic_sar__time_reversal_asymmetry_statistic__lag_3: 0.7811 (+)
#   15. tsfresh_ema_50__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4: 0.7789 (+)
#   16. tsfresh_ema_50__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4: 0.7789 (+)
#   17. tsfresh_ema_50_slope__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 