# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import Dict, List, Optional, Union
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    
from data_handle import(
    ForexDataClean,
    ForexDataLoad
)
from features import ForexFeauturesExtractor

import warnings
warnings.filterwarnings('ignore')


data = ForexDataLoad(file_path = '../data/xauaud.csv').data
ohlcv_data = ForexDataLoad(file_path = '../data/xauaud.csv').data

cleaner = ForexDataClean(data = data, fast_clean = True)
data = cleaner.data
# Out:
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA LOADER
# ==================================================
#  Available Fuctions
# 1 load_csv
# 2 load_from_database
# ==================================================
# Data loaded successfully!
# Shape: (38217, 5)
#
# ==================================================
# ==================================================
# FOREX DATA CLEANER
# ==================================================
#  Available Fuctions
# 1 remove_duplicates
# 2 handle_missing_values
# 3 validate_ohlc_integrity
# 4 handle_outliers
# ==================================================
# ==================================================
# Keep = first and subset = None
# Removed 0 duplicate entries
# Found 1 missing values
#  dropped: 1 missing values .
# ==================================================
# OUTLIER DETECTION AND HANDLING
# ==================================================
# Method: quantile, Strategy: cap, Threshold: 3.0
# Remove outliers: False
# --------------------------------------------------
# open: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.81300 - 5218.90300]
# Original range: [1674.10000 - 5476.98000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# high: Found 764 outliers (381 low, 383 high)
# Bounds: [1819.15000 - 5224.87300]
# Original range: [1676.91000 - 5483.78000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# low: Found 766 outliers (383 low, 383 high)
# Bounds: [1816.29450 - 5211.65900]
# Original range: [1671.60000 - 5474.51000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# close: Found 766 outliers (383 low, 383 high)
# Bounds: [1817.85250 - 5218.90300]
# Original range: [1672.21000 - 5477.23000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# volume: Found 48 outliers (0 low, 48 high)
# Bounds: [0.00000 - 0.00000]
# Original range: [0.00000 - 9910.00000]
# Method: Quantile (1%-99%)
# Outliers detected but not removed (remove=False)
#
# ==================================================
# SUMMARY: Found 3110 outliers (not removed)
# Use remove=True to handle these outliers
# ==================================================
# ==================================================
# OHLC DATA INTEGRITY VALIDATION
# ==================================================
# No OHLC integrity violations found
# All OHLC values are consistent

# %%
features = ForexFeauturesExtractor(
    data = data
)

# %%
df = features.extract_all_features()

# %%
df.tail(10)
# Out:
#                        close     rsi_14  rsi_14_slope     rsi_21  \
# datetime
# 2025-09-05 11:00:00  5417.88  39.924414     -1.763241  45.570117
# 2025-09-05 12:00:00  5427.42  45.864889      5.940475  49.169326
# 2025-09-05 13:00:00  5427.78  46.081560      0.216670  49.302158
# 2025-09-05 14:00:00  5431.70  48.498726      2.417166  50.772957
# 2025-09-05 15:00:00  5447.40  56.843485      8.344759  56.125706
# 2025-09-05 16:00:00  5455.01  60.208992      3.365507  58.426432
# 2025-09-05 17:00:00  5474.64  67.294154      7.085162  63.596775
# 2025-09-05 18:00:00  5468.49  63.480472     -3.813682  61.097193
# 2025-09-05 19:00:00  5476.84  66.275040      2.794568  63.161323
# 2025-09-05 13:00:00                      5460.679783
# 2025-09-05 14:00:00                      5459.666922
# 2025-09-05 15:00:00                      5467.211146
# 2025-09-05 16:00:00                      5470.507527
# 2025-09-05 17:00:00                      5475.358508
# 2025-09-05 18:00:00                      5478.231465
# 2025-09-05 19:00:00                      5481.376762
# 2025-09-05 20:00:00                      5481.805679
#
#                      keltner_ema_20_atr_10_2.0_lower  std_dev_20  std_dev_50  \
# datetime
# 2025-09-05 11:00:00                      5409.004298    9.324447   14.322061
# 2025-09-05 12:00:00                      5408.447034    9.794178   14.202413
# 2025-09-05 13:00:00                      5409.069671   10.141455   14.212468
# 2025-09-05 14:00:00                      5409.477822   10.122387   14.017003
# 2025-09-05 15:00:00                      5404.376956    9.602899   14.059145
# 2025-09-05 16:00:00                      5404.740756    9.501006   13.886057
# 2025-09-05 17:00:00                      5406.940414   12.304267   14.742737
# 2025-09-05 18:00:00                      5409.275180   13.734463   15.324239
# 2025-09-05 19:00:00                      5412.432106   15.728269   16.202972
# 2025-09-05 20:00:00                      5417.779488   17.332776   17.065102
#
#                      std_dev_100
# datetime
# 2025-09-05 11:00:00    57.792779
# 2025-09-05 12:00:00    56.634311
# 2025-09-05 13:00:00    55.188630
# 2025-09-05 14:00:00    54.256884
# 2025-09-05 15:00:00    53.994257
# 2025-09-05 16:00:00    53.575516
# 2025-09-05 17:00:00    53.428630
# 2025-09-05 18:00:00    53.194591
# 2025-09-05 19:00:00    53.074741
# 2025-09-05 20:00:00    52.827657
#
# [10 rows x 93 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38216 entries, 2017-04-24 02:00:00 to 2025-09-05 20:00:00
# Data columns (total 93 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   close                             38216 non-null  float64
#  1   rsi_14                            38202 non-null  float64
#  2   rsi_14_slope                      38201 non-null  float64
#  3   rsi_21                            38195 non-null  float64
#  4   rsi_21_slope                      38194 non-null  float64
#  5   rsi_28                            38188 non-null  float64
#  6   rsi_28_slope                      38187 non-null  float64
#  7   stoch_slowk_3                     38199 non-null  float64
#  8   stoch_slowd_3                     38199 non-null  float64
#  9   stoch_slowk_3_slope               38198 non-null  float64
#  10  stoch_slowd_3_slope               38198 non-null  float64
#  11  williams_r_14                     38203 non-null  float64
#  12  williams_r_14_slope               38202 non-null  float64
#  13  williams_r_21                     38196 non-null  float64
#  14  williams_r_21_slope               38195 non-null  float64
#  15  williams_r_28                     38189 non-null  float64
#  16  williams_r_28_slope               38188 non-null  float64
#  17  cci_14                            38203 non-null  float64
#  18  cci_14_slope                      38202 non-null  float64
#  19  cci_21                            38196 non-null  float64
#  20  cci_21_slope                      38195 non-null  float64
#  21  cci_28                            38189 non-null  float64
#  22  cci_28_slope                      38188 non-null  float64
#  23  momentum_10                       38206 non-null  float64
#  24  momentum_10_slope                 38205 non-null  float64
#  25  momentum_14                       38202 non-null  float64
#  26  momentum_14_slope                 38201 non-null  float64
#  27  momentum_20                       38196 non-null  float64
#  28  momentum_20_slope                 38195 non-null  float64
#  29  close                             38216 non-null  float64
#  30  sma_10                            38207 non-null  float64
#  31  sma_10_slope                      38206 non-null  float64
#  32  sma_20                            38197 non-null  float64
#  33  sma_20_slope                      38196 non-null  float64
#  34  sma_50                            38167 non-null  float64
#  35  sma_50_slope                      38166 non-null  float64
#  36  sma_100                           38117 non-null  float64
#  37  sma_100_slope                     38116 non-null  float64
#  38  sma_200                           38017 non-null  float64
#  39  sma_200_slope                     38016 non-null  float64
#  40  ema_10                            38207 non-null  float64
#  41  ema_10_slope                      38206 non-null  float64
#  42  ema_20                            38197 non-null  float64
#  43  ema_20_slope                      38196 non-null  float64
#  44  ema_50                            38167 non-null  float64
#  45  ema_50_slope                      38166 non-null  float64
#  46  ema_100                           38117 non-null  float64
#  47  ema_100_slope                     38116 non-null  float64
#  48  ema_200                           38017 non-null  float64
#  49  ema_200_slope                     38016 non-null  float64
#  50  macd_12_26                        38183 non-null  float64
#  51  macd_signal_9                     38183 non-null  float64
#  52  macd_hist_fast_12_slow26_sig9     38183 non-null  float64
#  53  macd_12_26_slope                  38182 non-null  float64
#  54  macd_signal_9_slope               38182 non-null  float64
#  55  adx_14                            38189 non-null  float64
#  56  adx_14_plus                       38202 non-null  float64
#  57  adx_14_minus                      38202 non-null  float64
#  58  adx_14_slope                      38188 non-null  float64
#  59  adx_14_plus_di_slope              38201 non-null  float64
#  60  adx_14_minus_di_slope             38201 non-null  float64
#  61  adx_21                            38175 non-null  float64
#  62  adx_21_plus                       38195 non-null  float64
#  63  adx_21_minus                      38195 non-null  float64
#  64  adx_21_slope                      38174 non-null  float64
#  65  adx_21_plus_di_slope              38194 non-null  float64
#  66  adx_21_minus_di_slope             38194 non-null  float64
#  67  adx_28                            38161 non-null  float64
#  68  adx_28_plus                       38188 non-null  float64
#  69  adx_28_minus                      38188 non-null  float64
#  70  adx_28_slope                      38160 non-null  float64
#  71  adx_28_plus_di_slope              38187 non-null  float64
#  72  adx_28_minus_di_slope             38187 non-null  float64
#  73  sar_0.02_0.2                      38215 non-null  float64
#  74  sar_0.02_0.2_slope                38214 non-null  float64
#  75  close                             38216 non-null  float64
#  76  atr_14                            38202 non-null  float64
#  77  atr_14_slope                      38201 non-null  float64
#  78  atr_21                            38195 non-null  float64
#  79  atr_21_slope                      38194 non-null  float64
#  80  atr_28                            38188 non-null  float64
#  81  atr_28_slope                      38187 non-null  float64
#  82  bb_20_2.0_2.0_upper               38197 non-null  float64
#  83  bb_20_2.0_2.0_middle              38197 non-null  float64
#  84  bb_20_2.0_2.0_lower               38197 non-null  float64
#  85  atr_10                            38206 non-null  float64
#  86  atr_10_slope                      38205 non-null  float64
#  87  keltner_ema_20_atr_10_2.0_middle  38197 non-null  float64
#  88  keltner_ema_20_atr_10_2.0_upper   38197 non-null  float64
#  89  keltner_ema_20_atr_10_2.0_lower   38197 non-null  float64
#  90  std_dev_20                        38197 non-null  float64
#  91  std_dev_50                        38167 non-null  float64
#  92  std_dev_100                       38117 non-null  float64
# dtypes: float64(93)
# memory usage: 27.4 MB
