# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns   
import os   
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)
    
import src.data as dt
import src.feature_engineering as fe

# %%
df = dt.get_data(file_path='../data/xauaud.csv', symbole='XAU/AUD')
# Out:
# First 5 rows:
#                        Close
# Time
# 2023-05-12 01:00:00  3006.99
# 2023-05-12 02:00:00  3008.28
# 2023-05-12 03:00:00  3006.20
# 2023-05-12 04:00:00  3002.13
# 2023-05-12 05:00:00  2999.94
#
# Last 5 rows:
#                        Close
# Time
# 2025-09-05 13:00:00  5427.78
# 2025-09-05 14:00:00  5431.70
# 2025-09-05 15:00:00  5447.40
# 2025-09-05 16:00:00  5455.01
# 2025-09-05 17:00:00  5464.04
#
# Shape: (13713, 1)
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13713 entries, 2023-05-12 01:00:00 to 2025-09-05 17:00:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   13713 non-null  float64
# dtypes: float64(1)
# memory usage: 214.3 KB
# Info: None
#
# Null values:
# Close    0
# dtype: int64
#
# Duplicated values: 734
#
# Data types:
# Close    float64
# dtype: object
#
# Statistics:
#               Close
# count  13713.000000
# mean    3824.403869
# std      809.643458
# min     2831.280000
# 25%     3055.430000
# 50%     3621.910000
# 75%     4554.510000
# max     5464.040000

# %%
df = fe.pct_and_lags(df, num_lags=5)
# Out:
# First 5 rows:
#                        Close  PercentageChange  Close_Lag_1  Close_Lag_2  \
# Time
# 2023-05-12 07:00:00  3002.31           -0.0009       0.0017      -0.0007
# 2023-05-12 08:00:00  3000.88           -0.0005      -0.0009       0.0017
# 2023-05-12 09:00:00  3000.47           -0.0001      -0.0005      -0.0009
# 2023-05-12 10:00:00  3003.27            0.0009      -0.0001      -0.0005
# 2023-05-12 11:00:00  2997.39           -0.0020       0.0009      -0.0001
#
#                      Close_Lag_3  Close_Lag_4  Close_Lag_5
# Time
# 2023-05-12 07:00:00      -0.0014      -0.0007       0.0004
# 2023-05-12 08:00:00      -0.0007      -0.0014      -0.0007
# 2023-05-12 09:00:00       0.0017      -0.0007      -0.0014
# 2023-05-12 10:00:00      -0.0009       0.0017      -0.0007
# 2023-05-12 11:00:00      -0.0005      -0.0009       0.0017
# ------------------------------------------------------------
# Last 5 rows:
#                        Close  PercentageChange  Close_Lag_1  Close_Lag_2  \
# Time
# 2025-09-05 13:00:00  5427.78            0.0001       0.0018      -0.0007
# 2025-09-05 14:00:00  5431.70            0.0007       0.0001       0.0018
# 2025-09-05 15:00:00  5447.40            0.0029       0.0007       0.0001
# 2025-09-05 16:00:00  5455.01            0.0014       0.0029       0.0007
# 2025-09-05 17:00:00  5464.04            0.0017       0.0014       0.0029
#
#                      Close_Lag_3  Close_Lag_4  Close_Lag_5
# Time
# 2025-09-05 13:00:00      -0.0029      -0.0009      -0.0015
# 2025-09-05 14:00:00      -0.0007      -0.0029      -0.0009
# 2025-09-05 15:00:00       0.0018      -0.0007      -0.0029
# 2025-09-05 16:00:00       0.0001       0.0018      -0.0007
# 2025-09-05 17:00:00       0.0007       0.0001       0.0018
# Shape: (13707, 7)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13707 entries, 2023-05-12 07:00:00 to 2025-09-05 17:00:00
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Close             13707 non-null  float64
#  1   PercentageChange  13707 non-null  float64
#  2   Close_Lag_1       13707 non-null  float64
#  3   Close_Lag_2       13707 non-null  float64
#  4   Close_Lag_3       13707 non-null  float64
#  5   Close_Lag_4       13707 non-null  float64
#  6   Close_Lag_5       13707 non-null  float64
# dtypes: float64(7)
# memory usage: 856.7 KB
# Info: None
# Null values:
# Close               0
# PercentageChange    0
# Close_Lag_1         0
# Close_Lag_2         0
# Close_Lag_3         0
# Close_Lag_4         0
# Close_Lag_5         0
# dtype: int64
# Duplicated values: 0
# Data types:
# Close               float64
# PercentageChange    float64
# Close_Lag_1         float64
# Close_Lag_2         float64
# Close_Lag_3         float64
# Close_Lag_4         float64
# Close_Lag_5         float64
# dtype: object
# Statistics:
#               Close  PercentageChange   Close_Lag_1   Close_Lag_2  \
# count  13707.000000      13707.000000  13707.000000  13707.000000
# mean    3824.762661          0.000046      0.000046      0.000046
# std      809.638964          0.001855      0.001855      0.001855
# min     2831.280000         -0.029500     -0.029500     -0.029500
# 25%     3055.840000         -0.000800     -0.000800     -0.000800
# 50%     3622.560000          0.000000      0.000000      0.000000
# 75%     4554.980000          0.000900      0.000900      0.000900
# max     5464.040000          0.020100      0.020100      0.020100
#
#         Close_Lag_3   Close_Lag_4   Close_Lag_5
# count  13707.000000  13707.000000  13707.000000
# mean       0.000045      0.000045      0.000045
# std        0.001855      0.001855      0.001855
# min       -0.029500     -0.029500     -0.029500
# 25%       -0.000800     -0.000800     -0.000800
# 50%        0.000000      0.000000      0.000000
# 75%        0.000900      0.000900      0.000900
# max        0.020100      0.020100      0.020100
